# %%
#String Formating merupakan metode penggabungan teks dengan variabel
#kita akan menggunakan F string, yaitu metode paling baru dari versi 3.6 ke atas
#kita dapat langsung menempatkan variabel dalam string dengan {} kurung kurawal, dan mendahului string dengan huruf f
#contohnya print(f"halo guys nama saya {data_nama} saya berumur {data_umur}")

###################################################################################################
nama = 'Asep'
nilai_snbt = 360 #integer
prodi = 'Dokter'
Lulus = True
##################################################################################################

# %%
print(nama)
print(f"Nama Peserta: {nama}")

print(f"nama saya adalah {nama}")


print("nama lengkap saya adalah " + nama + " saya dari prodi " + prodi)
print("nama lengkap saya adalah " + nama + " saya mendapat nilai " + str(nilai_snbt))
# Out:
# Asep
# Nama Peserta: Asep
# nama saya adalah Asep
# nama lengkap saya adalah Asep saya dari prodi Dokter
# nama lengkap saya adalah Asep saya mendapat nilai 360

# %%
print(f"nama lengkap saya adalah {nama} saya mendapat nilai {nilai_snbt}")
# Out:
# nama lengkap saya adalah Asep saya mendapat nilai 360
